# %%
import numpy as np
import pandas as pd

# %%
s = pd.Series(np.random.randint(1,1000,size=(1000)))
# s
s.head()
s.tail()
s.head(10)
s.tail(20)
# Out:
# 980    535
# 981     54
# 982    442
# 983    825
# 984    178
# 985     53
# 986    840
# 987    395
# 988    231
# 989    820
# 990    575
# 991    710
# 992    255
# 993    602
# 994     99
# 995    169
# 996    433
# 997    121
# 998    787
# 999    158
# dtype: int32

# %%
# attributes
df = pd.DataFrame(np.random.randint(1,20,size=(5,4)), index = ['one','two','three','four','five'], columns = ['A','B','C','D'])
df
df.shape # gives dims like ndarray
df[:2]
df.columns = [x.lower() for x in df.columns]
df.columns
df
# to get actual data
s.array
s.index
s.index.array
s.to_numpy()
np.asarray(s)
# Out:
# array([364, 478, 458, 276, 244, 284,  26, 341, 725, 414, 882, 523, 345,
#        190, 782, 378, 384, 395, 896, 160, 127, 612, 695, 173, 327, 517,
#        151, 456, 610, 975, 411, 815, 132, 268, 572, 869, 566, 814, 322,
#        403, 407, 986, 988, 777, 288, 167, 373, 875, 392, 758, 754, 724,
#         25, 857, 306, 384, 929, 315, 753, 111, 233, 513, 896, 486, 215,
#        750, 337, 755, 513, 430, 182, 492, 174, 436, 343,  75, 979, 283,
#        777, 347, 673, 483, 402, 173, 507, 354,  36,  11, 586, 309, 550,
#        737, 757, 965, 735,   1, 769, 139, 415, 562, 153, 430,  72, 673,
#         78, 501, 592, 589, 624, 324, 637, 116,  32, 680, 630, 307, 907,
#        285,  24, 974, 393, 736, 290, 505, 409, 686, 363, 276, 743, 404,
#        179, 816, 927, 860, 566, 392, 897, 171, 532, 875, 712,  17,  42,
#        438, 492, 987, 921, 144, 629, 907, 955, 904, 532, 192, 666,  16,
#        286, 327, 139, 544, 460, 236, 799, 689, 379,  12, 627,  11, 241,
#        166, 518, 889,  64, 641, 506, 968,  13, 610,  20, 312, 228, 465,
#         27, 606, 435, 926, 390, 577, 787, 990, 263, 497, 537, 999, 303,
#        758, 466, 329, 893, 371, 998, 294, 685,  62, 778, 257, 824, 861,
#        944, 817, 636, 820,  85, 879, 790, 426, 529,  86, 395, 662, 391,
#        492, 138, 258,  61, 497, 930, 982, 775, 223, 292, 756, 223, 138,
#        381, 153, 250, 867, 819, 217,  29, 759, 183, 664, 277, 352, 570,
#        531, 331, 947, 316, 941, 610, 836, 601, 489,  95, 700, 440, 403,
#        835, 227, 535, 131, 420, 689, 270, 581, 602, 282, 154, 345, 943,
#        601, 198, 792, 642, 740, 758, 641, 684, 395, 879, 405, 117, 594,
#        728, 391, 428, 875,  56, 210, 691, 125, 606, 381,   4, 413, 640,
#        899, 764, 819, 621, 272, 696, 891, 235, 515, 530, 584, 775, 299,
#        550, 834, 147,  15,  87, 434, 685, 132, 292, 678, 716, 913, 977,
#        529, 328, 589, 313,  77, 647, 913, 451, 311, 775, 466, 479, 299,
#        350, 519,   3, 905, 352, 632, 377, 484, 980, 594, 108, 303, 174,
#        913, 284, 382,  54, 985,  61, 309, 524,  52, 270, 980, 577,  28,
#         15, 762, 417, 382, 496, 140, 794, 713, 673, 545, 542, 100,  16,
#        727, 929, 364, 115, 173, 790,   9, 215,  37, 451, 973,  81,  95,
#        678, 546, 767, 469, 873, 504,  88, 211, 897, 813, 957, 945,  87,
#        396,  54, 185, 469, 478, 347, 959, 994, 307, 984, 583,  62, 240,
#        279, 410, 986, 329, 651,  56, 434, 952, 120, 597, 450,  91, 832,
#        780,  46, 412, 538, 788, 765, 546, 448,  54, 479, 905, 933, 154,
#        900, 201, 497,  79, 222, 564, 959, 727, 582, 765, 132, 855, 293,
#        113, 712, 725, 171, 190, 791, 806, 603, 231, 133,  26, 420, 519,
#        650, 420, 594, 207, 817, 124, 229,   8, 504, 406, 130, 229, 187,
#        314, 849, 538, 764, 925, 223,  94, 964, 746, 955, 324, 180, 137,
#        507, 648, 322, 253, 539, 926, 763, 485, 628, 726,  99, 236, 833,
#        878, 427, 484, 970, 237, 986, 605,  27, 487, 122, 499, 238, 720,
#        425, 786, 316, 348, 645, 279, 131, 906, 925, 537, 207, 206, 409,
#        796, 162, 477, 947, 815, 512, 328, 947, 876, 873, 488, 454, 149,
#         61, 999, 596,  59, 824, 454, 484, 784,  37, 294, 690, 182, 953,
#        326, 153, 386, 890,  42, 397, 972, 654, 206, 334,  84, 902, 769,
#        441, 382, 377, 831, 987, 615, 270, 455, 334, 218,  91, 850, 163,
#         21, 633, 973, 324, 545, 654, 591, 241, 895, 222, 125, 955, 851,
#        757, 948, 998, 732,  66, 650, 756, 692, 187,  51, 490, 944, 790,
#        637, 509, 106, 607, 332, 653, 939, 754,  70, 484, 787, 634, 286,
#         45, 194,  88, 566, 573, 895,  60, 218,  67, 887, 618, 552, 653,
#        425, 144,  89, 423, 329, 571, 482, 406, 545, 846, 898, 154, 975,
#        474,  77, 856, 846, 762, 801, 166, 574, 112, 343, 232, 612, 317,
#        885, 275, 656,  60, 168, 745, 887, 695, 796, 527, 314, 725, 559,
#        587, 720, 277, 409, 313, 482, 833, 304, 443, 302, 827, 997,  24,
#        709, 308, 523, 926, 968, 147, 418, 512, 224, 432, 306, 884, 301,
#        404, 860, 744, 321, 614,  82, 962,  82, 544, 522, 151,  84,  59,
#        522, 836, 631, 345, 472, 322, 837, 837, 815, 188, 861, 760, 656,
#        266, 362, 175, 313, 574, 327, 628, 512, 272, 571, 227, 578,  39,
#        254, 559, 294, 132,  52, 589, 185,  66, 236,  86, 159, 230, 132,
#        343, 872, 517, 553, 523, 692, 898,  46, 686, 214, 483, 157, 508,
#        767, 893, 420, 859, 965, 348, 398, 163, 611, 277, 580, 644, 513,
#        359, 566, 314, 894, 690, 248, 262, 747, 484, 352, 657, 544, 411,
#        325, 437, 493, 946, 216, 663, 229,  25, 274, 665, 712, 356, 223,
#        409, 104, 230, 757, 538, 721,  53,  67, 367, 403, 178,  42, 158,
#         48, 126, 243, 633, 512, 242, 255, 221,  30, 729, 578,  46, 616,
#        665, 836, 534, 320, 463, 584, 923,  51, 103, 180, 573, 391,  93,
#        188, 805, 588, 496, 342, 825, 793, 488, 552, 974, 947, 730, 688,
#        956, 408, 145,  54, 373,  52, 143, 623,  14, 430, 850, 185, 820,
#        981,   6, 799, 686, 822, 326, 567, 536, 894, 459,  12, 179, 894,
#        604, 497, 138, 889, 484, 652, 588, 667, 361, 184, 708, 423, 252,
#        618, 258, 738, 862, 458, 686, 264,  58, 605, 479, 799, 280, 211,
#        883, 862,  42, 652, 614, 504, 980, 389, 628, 931, 884,   7, 193,
#        366, 859, 356, 795, 748, 155, 452, 891,  15, 541, 183, 579, 793,
#         88,  47, 260, 203, 573, 243, 719, 890, 371, 195, 741, 261, 231,
#        831, 921, 335, 618, 959, 723, 444, 643, 154, 572, 303, 494, 388,
#        243, 852, 798, 786, 656, 207, 227, 661, 341, 216, 880, 134, 209,
#        468, 407, 813, 370, 804, 535,  54, 442, 825, 178,  53, 840, 395,
#        231, 820, 575, 710, 255, 602,  99, 169, 433, 121, 787, 158],
#       dtype=int32)
