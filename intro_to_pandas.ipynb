# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series(np.random.randn(5),index = ['A','B','C','D','E'])
s
# Out:
# A   -0.953318
# B   -0.068852
# C    0.412614
# D   -1.642903
# C    1.453844
# dtype: float64
