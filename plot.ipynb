# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({"Hours Studies" : [1.0, 1.5, 2.0, 2.2, 2.8,
        3.0, 3.4, 3.8, 4.0, 4.3,
        4.8, 5.0, 5.2, 5.6, 6.0,
        6.3, 6.8, 7.0, 7.4, 7.8,
        8.0, 8.4, 8.8, 9.2, 9.5,
        10.0, 10.5, 11.0, 11.5, 12.0],
"Exam Score" : [41, 35, 49, 45, 58,
        52, 61, 54, 67, 60,
        71, 62, 75, 69, 81,
        73, 86, 77, 89, 82,
        92, 85, 95, 88, 97,
        91, 99, 93, 100, 96]})
print(df)
# Out:
#     Hours Studies  Exam Score
# 0             1.0          41
# 1             1.5          35
# 2             2.0          49
# 3             2.2          45
# 4             2.8          58
# 5             3.0          52
# 6             3.4          61
# 7             3.8          54
# 8             4.0          67
# 9             4.3          60
# 10            4.8          71
# 11            5.0          62
# 12            5.2          75
# 13            5.6          69
# 14            6.0          81
# 15            6.3          73
# 16            6.8          86
# 17            7.0          77
# 18            7.4          89
# 19            7.8          82
# 20            8.0          92
# 21            8.4          85
# 22            8.8          95
# 23            9.2          88
# 24            9.5          97
# 25           10.0          91
# 26           10.5          99
# 27           11.0          93
# 28           11.5         100
# 29           12.0          96

# %%
plt.scatter(df["Hours Studies"],df["Exam Score"])
plt.title("Hours Studied vs Exam Score")
plt.xlabel("Hours Studied")
plt.ylabel("Exam Score")
# Out:
# Text(0, 0.5, 'Exam Score')

# %%
df_next = pd.DataFrame({"Exam Score" : [32, 38, 41, 44, 46, 49, 50, 52, 54, 56,
        58, 60, 61, 63, 65, 66, 68, 69, 70, 72,
        73, 74, 75, 76, 77, 79, 80, 81, 82, 83,
        84, 85, 86, 87, 88, 89, 90, 91, 92, 93,
        94, 95, 96, 97, 98, 99, 67, 71, 78, 62]})

# %%
plt.hist(df["Exam Score"],edgecolor="black",color="cyan")
plt.title("Distribution of exam scores")
plt.xlabel("Score")
plt.ylabel("No. of students")
# Out:
# Text(0, 0.5, 'No. of students')

# %%
df_box = pd.DataFrame({"Class A" : [42, 45, 48, 50, 52, 54, 55, 56, 58, 59,
        60, 61, 62, 63, 64, 65, 66, 67, 68, 69],})
plt.boxplot(df_box,label=['Class A'],vert=False)
plt.title('Exam Scores')
plt.xlabel('Score')
# Out:
# C:\Users\diksh\AppData\Local\Temp\ipykernel_21204\3872936484.py:3: MatplotlibDeprecationWarning: vert: bool was deprecated in Matplotlib 3.11 and will be removed in 3.13. Use orientation: {'vertical', 'horizontal'} instead.
#   plt.boxplot(df_box,label=['Class A'],vert=False)
# Text(0.5, 0, 'Score')
