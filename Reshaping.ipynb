# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"..\Numpy\music.csv")
df
# Out:
#            Artist   Genres  Listeners       Plays
# 0  Billie Holiday     Jazz    1300000  27000000.0
# 1    Jimi Hendrix     Rock    2700000  70000000.0
# 2     Miles Davis     Jazz    1500000  48000000.0
# 3             SIA      Pop    2000000  74000000.0
# 4    Led Zeppelin  3000000   80000000         NaN
# 5    Taylor Swift  2500000   90000000         NaN
